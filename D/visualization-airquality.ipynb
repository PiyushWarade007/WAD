# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'airquality.csv')

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     high
# 1             2   36.0    118.0   8.0    72      5    2   medium
# 2             3   12.0    149.0  12.6    74      5    3      low
# 3             4   18.0    313.0  11.5    62      5    4   medium
# 4             5    NaN      NaN  14.3    56      5    5      low
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      low
# 149         150    NaN    145.0  13.2    77      9   27      NaN
# 150         151   14.0    191.0  14.3    75      9   28      low
# 151         152   18.0    131.0   8.0    76      9   29      NaN
# 152         153   20.0    223.0  11.5    68      9   30      low
#
# [153 rows x 8 columns]

# %%
data=data.drop(columns='Unnamed: 0')

# %%
data.isnull().sum()
# Out:
# Ozone       37
# Solar.R      7
# Wind         0
# Temp         0
# Month        0
# Day          0
# Humidity    72
# dtype: int64

# %%
#Data Cleanning
data['Ozone']=data['Ozone'].fillna(data['Ozone'].mean())
data['Solar.R']=data['Solar.R'].fillna(data['Solar.R'].mean())
data['Humidity']=data['Humidity'].fillna(data['Humidity'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    0
# dtype: int64

# %%
#Scatter plot
plt.scatter(data['Solar.R'],data['Ozone'],color='blue')
plt.xlabel("Solar,R")
plt.ylabel("Ozone")
# Out:
# Text(0, 0.5, 'Ozone')

# %%
#bar plot
ozone=df.iloc[1:16,0]
days=df.iloc[1:16,5]
plt.bar(days,ozone,color='red',width=0.8)
plt.xlabel("days in may")
plt.ylabel("ozone range over 15 days")
# Out:
# Text(0.5, 0, 'days in may')

# %%
#line plot
ozone=data.iloc[1:16,0]
wind=data.iloc[1:16,2]
plt.plot(ozone,label='ozone')
plt.plot(wind,label='wind')
plt.legend()
plt.xlabel('days')
plt.ylabel('range over 15 days')
# Out:
# Text(0, 0.5, 'range over 15 days')

# %%
#pie Chart
labels=['Ozone','Solar.R','Wind','Temprature']
sizes=[data['Ozone'].mean(),data['Solar.R'].mean(),data['Wind'].mean(),data['Temp'].mean()]
colors=['red','green','yellow','blue']
explode=(0.1,0,0,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=140)
plt.title('Average Data')
plt.show()

# %%
#histogram
sns.histplot(data=data,x='Wind',kde=True)
# Out:
# <Axes: xlabel='Wind', ylabel='Count'>

# %%
#pair plot
sns.set(style='ticks')
sns.pairplot(data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#heat map
df=data.iloc[1:30,0:6]
ax=sns.heatmap(df)
